# %% [markdown]
# ## DenseNet Architecture via Tensorflow
# ### Packages

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Model
import tensorflow.keras.backend as K
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, ZeroPadding2D, Dense, Dropout, Activation, Convolution2D, Reshape, ReLU, Conv2D
from tensorflow.keras.layers import AveragePooling2D, GlobalAveragePooling2D, MaxPooling2D, BatchNormalization, concatenate

# %% [markdown]
# ### DenseNet architectures
# <div style="text-align:center;">
#     <img src="images/DenseNet_architectures_for_ImageNet.jpg" style="width:900px;height:450px;" />
#     <br>
#     <caption><center> <u> <font color='black'> <b></b>  </u><font color='black'><b>The DenseNet Architectures</b></center></caption>
# </div>
# DenseNet architectures for ImageNet. The growth rate for all the networks is k = 32. Note that each 'conv' layer shown in the table corresponds the sequence BN-ReLU-Conv.

# %% [markdown]
# ### Defining the convolutional block
# Each convolutional block after the input has the following sequence: BatchNormalization, followed by ReLU activation and then the actual Conv2D layer.

# %%
# BN-ReLU-Conv(BatchNormalization-ReLU-Convolution)
def conv_block(x,filters,kernel=1,strides=1):

    x = BatchNormalization()(x)
    
    x = ReLU()(x)
    x = Conv2D(filters, kernel, strides=strides,padding = 'same')(x)
    return x

# %% [markdown]
# ### Defining the Dense block
# Every dense block has two convolutions, with 1x1 and 3x3 sized kernels. In dense block 1, this is repeated 6 times, in dense block 2 it is repeated 12 times, in dense block 3, 24 times and finally in dense block 4, 16 times.
#
# <div style="text-align:center;">
#     <img src="images/dense_block.png" style="width:400px;height:400px;" />
#     <br>
#     <caption><center> <u> <font color='black'> <b></b>  </u><font color='black'><b>Dense Block</b></center></caption>
# </div>

# %%
def dense_block(x, repetition):

    for _ in range(repetition):
        y = conv_block(x, 4*filters)
        y = conv_block(y, filters, 3)
        x = concatenate([y,x])
    return x

# %% [markdown]
# ### Defining the transition layer
# In the transition layer, we are to reduce the number of channels to half of the existing channels.
# <div style="text-align:center;">
#     <img src="images/transition_layer.png" style="width:600px;height:450px;" />
#     <br>
#     <caption><center> <u> <font color='black'> <b></b>  </u><font color='black'><b>Transition Layer</b></center></caption>
# </div>

# %%
def transition_layer(x):

    x = conv_block(x, K.int_shape(x)[-1] //2) # convert shape's format to tuple format
    x = AveragePooling2D(2, strides = 2, padding = 'same')(x)
    return x

# %% [markdown]
# ### Build The DenseNet Architecture(DenseNet121, DenseNet169, DenseNet201, DenseNet264)
#
# Defines a class named DenseNet with an initializer that takes in input_shape, n_classes, and filters as arguments and initializes these instance variables.

# %%
class DenseNet:
    def __init__(self, input_shape, n_classes, filters=32):
        self.input_shape = input_shape
        self.n_classes = n_classes
        self.filters = filters
        
# Defines a convolutional block consisting of batch normalization, ReLU activation, and 2D convolution layers.
    def conv_block(self, x, filters, kernel=1, strides=1):
        # A helper function for creating a convolutional block in the DenseNet architecture. It applies batch normalization, 
        # ReLU activation, and convolutional layers with the specified filters, kernel size, and strides.
        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = Conv2D(filters, kernel, strides=strides, padding='same')(x)
        return x
    
# Defines a dense block consisting of multiple convolutional blocks with concatenation of outputs from previous blocks.
    def dense_block(self, x, repetition):
        # A helper function for creating a dense block in the DenseNet architecture. It applies the specified number of conv_block repetitions 
        # to the input tensor x, and concatenates the outputs of each conv_block along the channel axis.
        for _ in range(repetition):
            y = self.conv_block(x, 4 * self.filters)
            y = self.conv_block(y, self.filters, 3)
            x = concatenate([y, x])
        return x
    
# Defines a transition layer consisting of a convolutional block followed by an average pooling layer.
    def transition_layer(self, x):
        # A helper function for creating a transition layer in the DenseNet architecture. It applies a conv_block to 
        # the input tensor x to reduce the number of channels by half, and applies average pooling with a stride of 2 
        # to downsample the spatial dimensions by half.
        x = self.conv_block(x, K.int_shape(x)[-1] // 2)
        x = AveragePooling2D(2, strides=2, padding='same')(x)
        return x
    
#Defines a DenseNet121 model architecture consisting of multiple dense blocks and transition layers.
    def DenseNet121(self):
        input = Input(self.input_shape)
        x = ZeroPadding2D((3, 3), name='conv1_zeropadding')(input)
        x = Convolution2D(64, (7, 7), (2, 2), name='conv1')(x)
        x = BatchNormalization(name='conv1_bn')(x)
        x = Activation('relu', name='relu1')(x)
        x = ZeroPadding2D((1, 1), name='pool1_zeropadding')(x)
        x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1')(x)

        for repetition in [6, 12, 24, 16]:
            # The DenseNet-121 architecture consists of four dense blocks with 
            # 6, 12, 24, and 16 conv_block repetitions, respectively. After each 
            # dense block, a transition layer is applied.
            d = self.dense_block(x, repetition)
            x = self.transition_layer(d)

        x = GlobalAveragePooling2D()(d)
        # Finally, global average pooling is applied to the output of the last dense block,
        # and the resulting tensor is used as the output of the model.
#         output = Dense(self.n_classes, activation='softmax')(x)

        model = Model(input, x)
        return model
    
#Defines a DenseNet169 model architecture consisting of multiple dense blocks and transition layers. 
    def DenseNet169(self):
        input = Input(self.input_shape)
        x = ZeroPadding2D((3, 3), name='conv1_zeropadding')(input)
        x = Convolution2D(64, (7, 7), (2, 2), name='conv1')(x)
        x = BatchNormalization(name='conv1_bn')(x)
        x = Activation('relu', name='relu1')(x)
        x = ZeroPadding2D((1, 1), name='pool1_zeropadding')(x)
        x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1')(x)

        for repetition in [6, 12, 32, 32]:
            d = self.dense_block(x, repetition)
            x = self.transition_layer(d)

        x = GlobalAveragePooling2D()(d)
#         output = Dense(self.n_classes, activation='softmax')(x)

        model = Model(input, x)
        return model
    
#Defines a DenseNet201 model architecture consisting of multiple dense blocks and transition layers.   
    def DenseNet201(self):
        input = Input(self.input_shape)
        x = ZeroPadding2D((3, 3), name='conv1_zeropadding')(input)
        x = Convolution2D(64, (7, 7), (2, 2), name='conv1')(x)
        x = BatchNormalization(name='conv1_bn')(x)
        x = Activation('relu', name='relu1')(x)
        x = ZeroPadding2D((1, 1), name='pool1_zeropadding')(x)
        x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1')(x)

        for repetition in [6, 12, 48, 32]:
            d = self.dense_block(x, repetition)
            x = self.transition_layer(d)

        x = GlobalAveragePooling2D()(d)
#         output = Dense(self.n_classes, activation='softmax')(x)

        model = Model(input, x)
        return model
    
#Defines a DenseNet264 model architecture consisting of multiple dense blocks and transition layers. 
    def DenseNet264(self):
        input = Input(self.input_shape)
        x = ZeroPadding2D((3, 3), name='conv1_zeropadding')(input)
        x = Convolution2D(64, (7, 7), (2, 2), name='conv1')(x)
        x = BatchNormalization(name='conv1_bn')(x)
        x = Activation('relu', name='relu1')(x)
        x = ZeroPadding2D((1, 1), name='pool1_zeropadding')(x)
        x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1')(x)

        for repetition in [6, 12, 64, 48]:
            d = self.dense_block(x, repetition)
            x = self.transition_layer(d)

        x = GlobalAveragePooling2D()(d)
#         output = Dense(self.n_classes, activation='softmax')(x)

        model = Model(input, x)
        return model

# %%
densenet121 = DenseNet(input_shape=(224, 224, 3), n_classes=10).DenseNet121().summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_zeropadding (ZeroPadding  (None, 230, 230, 3)  0          ['input_2[0][0]']
#  2D)
#
#  conv1 (Conv2D)                 (None, 112, 112, 64  9472        ['conv1_zeropadding[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1[0][0]']
#                                 )
#
#  relu1 (Activation)             (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_zeropadding (ZeroPadding  (None, 114, 114, 64  0          ['relu1[0][0]']
#  2D)                            )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['pool1_zeropadding[0][0]']
#
#  batch_normalization_120 (Batch  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  Normalization)
#
#  re_lu_120 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_120[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 56, 56, 128)  8320        ['re_lu_120[0][0]']
#
#  batch_normalization_121 (Batch  (None, 56, 56, 128)  512        ['conv2d_120[0][0]']
#  Normalization)
#
#  re_lu_121 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_121[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 56, 56, 32)   36896       ['re_lu_121[0][0]']
#
#  concatenate_58 (Concatenate)   (None, 56, 56, 96)   0           ['conv2d_121[0][0]',
#                                                                   'pool1[0][0]']
#
#  batch_normalization_122 (Batch  (None, 56, 56, 96)  384         ['concatenate_58[0][0]']
#  Normalization)
#
#  re_lu_122 (ReLU)               (None, 56, 56, 96)   0           ['batch_normalization_122[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 56, 56, 128)  12416       ['re_lu_122[0][0]']
#
#  batch_normalization_123 (Batch  (None, 56, 56, 128)  512        ['conv2d_122[0][0]']
#  Normalization)
#
#  re_lu_123 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_123[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 56, 56, 32)   36896       ['re_lu_123[0][0]']
#
#  concatenate_59 (Concatenate)   (None, 56, 56, 128)  0           ['conv2d_123[0][0]',
#                                                                   'concatenate_58[0][0]']
#
#  batch_normalization_124 (Batch  (None, 56, 56, 128)  512        ['concatenate_59[0][0]']
#  Normalization)
#
#  re_lu_124 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_124[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 56, 56, 128)  16512       ['re_lu_124[0][0]']
#
#  batch_normalization_125 (Batch  (None, 56, 56, 128)  512        ['conv2d_124[0][0]']
#  Normalization)
#
#  re_lu_125 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_125[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 56, 56, 32)   36896       ['re_lu_125[0][0]']
#
#  concatenate_60 (Concatenate)   (None, 56, 56, 160)  0           ['conv2d_125[0][0]',
#                                                                   'concatenate_59[0][0]']
#
#  batch_normalization_126 (Batch  (None, 56, 56, 160)  640        ['concatenate_60[0][0]']
#  Normalization)
#
#  re_lu_126 (ReLU)               (None, 56, 56, 160)  0           ['batch_normalization_126[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 56, 56, 128)  20608       ['re_lu_126[0][0]']
#
#  batch_normalization_127 (Batch  (None, 56, 56, 128)  512        ['conv2d_126[0][0]']
#  Normalization)
#
#  re_lu_127 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_127[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 56, 56, 32)   36896       ['re_lu_127[0][0]']
#
#  concatenate_61 (Concatenate)   (None, 56, 56, 192)  0           ['conv2d_127[0][0]',
#                                                                   'concatenate_60[0][0]']
#
#  batch_normalization_128 (Batch  (None, 56, 56, 192)  768        ['concatenate_61[0][0]']
#  Normalization)
#
#  re_lu_128 (ReLU)               (None, 56, 56, 192)  0           ['batch_normalization_128[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 56, 56, 128)  24704       ['re_lu_128[0][0]']
#
#  batch_normalization_129 (Batch  (None, 56, 56, 128)  512        ['conv2d_128[0][0]']
#  Normalization)
#
#  re_lu_129 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_129[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 56, 56, 32)   36896       ['re_lu_129[0][0]']
#
#  concatenate_62 (Concatenate)   (None, 56, 56, 224)  0           ['conv2d_129[0][0]',
#                                                                   'concatenate_61[0][0]']
#
#  batch_normalization_130 (Batch  (None, 56, 56, 224)  896        ['concatenate_62[0][0]']
#  Normalization)
#
#  re_lu_130 (ReLU)               (None, 56, 56, 224)  0           ['batch_normalization_130[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 56, 56, 128)  28800       ['re_lu_130[0][0]']
#
#  batch_normalization_131 (Batch  (None, 56, 56, 128)  512        ['conv2d_130[0][0]']
#  Normalization)
#
#  re_lu_131 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_131[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 56, 56, 32)   36896       ['re_lu_131[0][0]']
#
#  concatenate_63 (Concatenate)   (None, 56, 56, 256)  0           ['conv2d_131[0][0]',
#                                                                   'concatenate_62[0][0]']
#
#  batch_normalization_132 (Batch  (None, 56, 56, 256)  1024       ['concatenate_63[0][0]']
#  Normalization)
#
#  re_lu_132 (ReLU)               (None, 56, 56, 256)  0           ['batch_normalization_132[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 56, 56, 128)  32896       ['re_lu_132[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 28, 28, 128)  0          ['conv2d_132[0][0]']
#  oling2D)
#
#  batch_normalization_133 (Batch  (None, 28, 28, 128)  512        ['average_pooling2d_4[0][0]']
#  Normalization)
#
#  re_lu_133 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_133[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 28, 28, 128)  16512       ['re_lu_133[0][0]']
#
#  batch_normalization_134 (Batch  (None, 28, 28, 128)  512        ['conv2d_133[0][0]']
#  Normalization)
#
#  re_lu_134 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_134[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_134[0][0]']
#
#  concatenate_64 (Concatenate)   (None, 28, 28, 160)  0           ['conv2d_134[0][0]',
#                                                                   'average_pooling2d_4[0][0]']
#
#  batch_normalization_135 (Batch  (None, 28, 28, 160)  640        ['concatenate_64[0][0]']
#  Normalization)
#
#  re_lu_135 (ReLU)               (None, 28, 28, 160)  0           ['batch_normalization_135[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 28, 28, 128)  20608       ['re_lu_135[0][0]']
#
#  batch_normalization_136 (Batch  (None, 28, 28, 128)  512        ['conv2d_135[0][0]']
#  Normalization)
#
#  re_lu_136 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_136[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_136[0][0]']
#  concatenate_65 (Concatenate)   (None, 28, 28, 192)  0           ['conv2d_136[0][0]',
#                                                                   'concatenate_64[0][0]']
#
#  batch_normalization_137 (Batch  (None, 28, 28, 192)  768        ['concatenate_65[0][0]']
#  Normalization)
#
#  re_lu_137 (ReLU)               (None, 28, 28, 192)  0           ['batch_normalization_137[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 28, 28, 128)  24704       ['re_lu_137[0][0]']
#
#  batch_normalization_138 (Batch  (None, 28, 28, 128)  512        ['conv2d_137[0][0]']
#  Normalization)
#
#  re_lu_138 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_138[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_138[0][0]']
#
#  concatenate_66 (Concatenate)   (None, 28, 28, 224)  0           ['conv2d_138[0][0]',
#                                                                   'concatenate_65[0][0]']
#
#  batch_normalization_139 (Batch  (None, 28, 28, 224)  896        ['concatenate_66[0][0]']
#  Normalization)
#
#  re_lu_139 (ReLU)               (None, 28, 28, 224)  0           ['batch_normalization_139[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 28, 28, 128)  28800       ['re_lu_139[0][0]']
#
#  batch_normalization_140 (Batch  (None, 28, 28, 128)  512        ['conv2d_139[0][0]']
#  Normalization)
#
#  re_lu_140 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_140[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_140[0][0]']
#
#  concatenate_67 (Concatenate)   (None, 28, 28, 256)  0           ['conv2d_140[0][0]',
#                                                                   'concatenate_66[0][0]']
#
#  batch_normalization_141 (Batch  (None, 28, 28, 256)  1024       ['concatenate_67[0][0]']
#  Normalization)
#
#  re_lu_141 (ReLU)               (None, 28, 28, 256)  0           ['batch_normalization_141[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 28, 28, 128)  32896       ['re_lu_141[0][0]']
#
#  batch_normalization_142 (Batch  (None, 28, 28, 128)  512        ['conv2d_141[0][0]']
#  Normalization)
#
#  re_lu_142 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_142[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_142[0][0]']
#
#  concatenate_68 (Concatenate)   (None, 28, 28, 288)  0           ['conv2d_142[0][0]',
#                                                                   'concatenate_67[0][0]']
#
#  batch_normalization_143 (Batch  (None, 28, 28, 288)  1152       ['concatenate_68[0][0]']
#  Normalization)
#
#  re_lu_143 (ReLU)               (None, 28, 28, 288)  0           ['batch_normalization_143[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 28, 28, 128)  36992       ['re_lu_143[0][0]']
#
#  batch_normalization_144 (Batch  (None, 28, 28, 128)  512        ['conv2d_143[0][0]']
#  Normalization)
#
#  re_lu_144 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_144[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_144[0][0]']
#
#  concatenate_69 (Concatenate)   (None, 28, 28, 320)  0           ['conv2d_144[0][0]',
#                                                                   'concatenate_68[0][0]']
#
#  batch_normalization_145 (Batch  (None, 28, 28, 320)  1280       ['concatenate_69[0][0]']
#  Normalization)
#
#  re_lu_145 (ReLU)               (None, 28, 28, 320)  0           ['batch_normalization_145[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 28, 28, 128)  41088       ['re_lu_145[0][0]']
#
#  batch_normalization_146 (Batch  (None, 28, 28, 128)  512        ['conv2d_145[0][0]']
#  Normalization)
#
#  re_lu_146 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_146[0][0]']
#  conv2d_146 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_146[0][0]']
#
#  concatenate_70 (Concatenate)   (None, 28, 28, 352)  0           ['conv2d_146[0][0]',
#                                                                   'concatenate_69[0][0]']
#
#  batch_normalization_147 (Batch  (None, 28, 28, 352)  1408       ['concatenate_70[0][0]']
#  Normalization)
#
#  re_lu_147 (ReLU)               (None, 28, 28, 352)  0           ['batch_normalization_147[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 28, 28, 128)  45184       ['re_lu_147[0][0]']
#
#  batch_normalization_148 (Batch  (None, 28, 28, 128)  512        ['conv2d_147[0][0]']
#  Normalization)
#
#  re_lu_148 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_148[0][0]']
#
#  concatenate_71 (Concatenate)   (None, 28, 28, 384)  0           ['conv2d_148[0][0]',
#                                                                   'concatenate_70[0][0]']
#
#  batch_normalization_149 (Batch  (None, 28, 28, 384)  1536       ['concatenate_71[0][0]']
#  Normalization)
#
#  re_lu_149 (ReLU)               (None, 28, 28, 384)  0           ['batch_normalization_149[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 28, 28, 128)  49280       ['re_lu_149[0][0]']
#
#  batch_normalization_150 (Batch  (None, 28, 28, 128)  512        ['conv2d_149[0][0]']
#  Normalization)
#
#  re_lu_150 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_150[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_150[0][0]']
#
#  concatenate_72 (Concatenate)   (None, 28, 28, 416)  0           ['conv2d_150[0][0]',
#                                                                   'concatenate_71[0][0]']
#
#  batch_normalization_151 (Batch  (None, 28, 28, 416)  1664       ['concatenate_72[0][0]']
#  Normalization)
#
#  re_lu_151 (ReLU)               (None, 28, 28, 416)  0           ['batch_normalization_151[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 28, 28, 128)  53376       ['re_lu_151[0][0]']
#
#  batch_normalization_152 (Batch  (None, 28, 28, 128)  512        ['conv2d_151[0][0]']
#  Normalization)
#
#  re_lu_152 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_152[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_152[0][0]']
#
#  concatenate_73 (Concatenate)   (None, 28, 28, 448)  0           ['conv2d_152[0][0]',
#                                                                   'concatenate_72[0][0]']
#
#  batch_normalization_153 (Batch  (None, 28, 28, 448)  1792       ['concatenate_73[0][0]']
#  Normalization)
#
#  re_lu_153 (ReLU)               (None, 28, 28, 448)  0           ['batch_normalization_153[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 28, 28, 128)  57472       ['re_lu_153[0][0]']
#
#  batch_normalization_154 (Batch  (None, 28, 28, 128)  512        ['conv2d_153[0][0]']
#  Normalization)
#
#  re_lu_154 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_154[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_154[0][0]']
#
#  concatenate_74 (Concatenate)   (None, 28, 28, 480)  0           ['conv2d_154[0][0]',
#                                                                   'concatenate_73[0][0]']
#
#  batch_normalization_155 (Batch  (None, 28, 28, 480)  1920       ['concatenate_74[0][0]']
#  Normalization)
#
#  re_lu_155 (ReLU)               (None, 28, 28, 480)  0           ['batch_normalization_155[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 28, 28, 128)  61568       ['re_lu_155[0][0]']
#
#  batch_normalization_156 (Batch  (None, 28, 28, 128)  512        ['conv2d_155[0][0]']
#  Normalization)
#  re_lu_156 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_156[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_156[0][0]']
#
#  concatenate_75 (Concatenate)   (None, 28, 28, 512)  0           ['conv2d_156[0][0]',
#                                                                   'concatenate_74[0][0]']
#
#  batch_normalization_157 (Batch  (None, 28, 28, 512)  2048       ['concatenate_75[0][0]']
#  Normalization)
#
#  re_lu_157 (ReLU)               (None, 28, 28, 512)  0           ['batch_normalization_157[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 28, 28, 256)  131328      ['re_lu_157[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 14, 14, 256)  0          ['conv2d_157[0][0]']
#  oling2D)
#
#  batch_normalization_158 (Batch  (None, 14, 14, 256)  1024       ['average_pooling2d_5[0][0]']
#  Normalization)
#
#  re_lu_158 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_158[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 14, 14, 128)  32896       ['re_lu_158[0][0]']
#
#  batch_normalization_159 (Batch  (None, 14, 14, 128)  512        ['conv2d_158[0][0]']
#  Normalization)
#
#  re_lu_159 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_159[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_159[0][0]']
#
#  concatenate_76 (Concatenate)   (None, 14, 14, 288)  0           ['conv2d_159[0][0]',
#                                                                   'average_pooling2d_5[0][0]']
#
#  batch_normalization_160 (Batch  (None, 14, 14, 288)  1152       ['concatenate_76[0][0]']
#  Normalization)
#
#  re_lu_160 (ReLU)               (None, 14, 14, 288)  0           ['batch_normalization_160[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 14, 14, 128)  36992       ['re_lu_160[0][0]']
#
#  batch_normalization_161 (Batch  (None, 14, 14, 128)  512        ['conv2d_160[0][0]']
#  Normalization)
#
#  re_lu_161 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_161[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_161[0][0]']
#
#  concatenate_77 (Concatenate)   (None, 14, 14, 320)  0           ['conv2d_161[0][0]',
#                                                                   'concatenate_76[0][0]']
#
#  batch_normalization_162 (Batch  (None, 14, 14, 320)  1280       ['concatenate_77[0][0]']
#  Normalization)
#
#  re_lu_162 (ReLU)               (None, 14, 14, 320)  0           ['batch_normalization_162[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 14, 14, 128)  41088       ['re_lu_162[0][0]']
#
#  batch_normalization_163 (Batch  (None, 14, 14, 128)  512        ['conv2d_162[0][0]']
#  Normalization)
#
#  re_lu_163 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_163[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_163[0][0]']
#
#  concatenate_78 (Concatenate)   (None, 14, 14, 352)  0           ['conv2d_163[0][0]',
#                                                                   'concatenate_77[0][0]']
#
#  batch_normalization_164 (Batch  (None, 14, 14, 352)  1408       ['concatenate_78[0][0]']
#  Normalization)
#
#  re_lu_164 (ReLU)               (None, 14, 14, 352)  0           ['batch_normalization_164[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 14, 14, 128)  45184       ['re_lu_164[0][0]']
#
#  batch_normalization_165 (Batch  (None, 14, 14, 128)  512        ['conv2d_164[0][0]']
#  Normalization)
#
#  re_lu_165 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_165[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_165[0][0]']
#
#  concatenate_79 (Concatenate)   (None, 14, 14, 384)  0           ['conv2d_165[0][0]',
#                                                                   'concatenate_78[0][0]']
#
#  batch_normalization_166 (Batch  (None, 14, 14, 384)  1536       ['concatenate_79[0][0]']
#  Normalization)
#
#  re_lu_166 (ReLU)               (None, 14, 14, 384)  0           ['batch_normalization_166[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 14, 14, 128)  49280       ['re_lu_166[0][0]']
#
#  batch_normalization_167 (Batch  (None, 14, 14, 128)  512        ['conv2d_166[0][0]']
#  Normalization)
#
#  re_lu_167 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_167[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_167[0][0]']
#
#  concatenate_80 (Concatenate)   (None, 14, 14, 416)  0           ['conv2d_167[0][0]',
#                                                                   'concatenate_79[0][0]']
#
#  batch_normalization_168 (Batch  (None, 14, 14, 416)  1664       ['concatenate_80[0][0]']
#  Normalization)
#
#  re_lu_168 (ReLU)               (None, 14, 14, 416)  0           ['batch_normalization_168[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 14, 14, 128)  53376       ['re_lu_168[0][0]']
#
#  batch_normalization_169 (Batch  (None, 14, 14, 128)  512        ['conv2d_168[0][0]']
#  Normalization)
#
#  re_lu_169 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_169[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_169[0][0]']
#
#  concatenate_81 (Concatenate)   (None, 14, 14, 448)  0           ['conv2d_169[0][0]',
#                                                                   'concatenate_80[0][0]']
#
#  batch_normalization_170 (Batch  (None, 14, 14, 448)  1792       ['concatenate_81[0][0]']
#  Normalization)
#
#  re_lu_170 (ReLU)               (None, 14, 14, 448)  0           ['batch_normalization_170[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 14, 14, 128)  57472       ['re_lu_170[0][0]']
#
#  batch_normalization_171 (Batch  (None, 14, 14, 128)  512        ['conv2d_170[0][0]']
#  Normalization)
#
#  re_lu_171 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_171[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_171[0][0]']
#
#  concatenate_82 (Concatenate)   (None, 14, 14, 480)  0           ['conv2d_171[0][0]',
#                                                                   'concatenate_81[0][0]']
#
#  batch_normalization_172 (Batch  (None, 14, 14, 480)  1920       ['concatenate_82[0][0]']
#  Normalization)
#
#  re_lu_172 (ReLU)               (None, 14, 14, 480)  0           ['batch_normalization_172[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 14, 14, 128)  61568       ['re_lu_172[0][0]']
#
#  batch_normalization_173 (Batch  (None, 14, 14, 128)  512        ['conv2d_172[0][0]']
#  Normalization)
#
#  re_lu_173 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_173[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_173[0][0]']
#
#  concatenate_83 (Concatenate)   (None, 14, 14, 512)  0           ['conv2d_173[0][0]',
#                                                                   'concatenate_82[0][0]']
#
#  batch_normalization_174 (Batch  (None, 14, 14, 512)  2048       ['concatenate_83[0][0]']
#  Normalization)
#
#  re_lu_174 (ReLU)               (None, 14, 14, 512)  0           ['batch_normalization_174[0][0]']
# ...
#
#  concatenate_106 (Concatenate)  (None, 7, 7, 736)    0           ['conv2d_220[0][0]',
#                                                                   'concatenate_105[0][0]']
#
#  batch_normalization_221 (Batch  (None, 7, 7, 736)   2944        ['concatenate_106[0][0]']
#  Normalization)
#
#  re_lu_221 (ReLU)               (None, 7, 7, 736)    0           ['batch_normalization_221[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 7, 7, 128)    94336       ['re_lu_221[0][0]']
#
#  batch_normalization_222 (Batch  (None, 7, 7, 128)   512         ['conv2d_221[0][0]']
#  Normalization)
#
#  re_lu_222 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_222[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_222[0][0]']
#
#  concatenate_107 (Concatenate)  (None, 7, 7, 768)    0           ['conv2d_222[0][0]',
#                                                                   'concatenate_106[0][0]']
#
#  batch_normalization_223 (Batch  (None, 7, 7, 768)   3072        ['concatenate_107[0][0]']
#  Normalization)
#
#  re_lu_223 (ReLU)               (None, 7, 7, 768)    0           ['batch_normalization_223[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 7, 7, 128)    98432       ['re_lu_223[0][0]']
#
#  batch_normalization_224 (Batch  (None, 7, 7, 128)   512         ['conv2d_223[0][0]']
#  Normalization)
#
#  re_lu_224 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_224[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_224[0][0]']
#
#  concatenate_108 (Concatenate)  (None, 7, 7, 800)    0           ['conv2d_224[0][0]',
#                                                                   'concatenate_107[0][0]']
#
#  batch_normalization_225 (Batch  (None, 7, 7, 800)   3200        ['concatenate_108[0][0]']
#  Normalization)
#
#  re_lu_225 (ReLU)               (None, 7, 7, 800)    0           ['batch_normalization_225[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 7, 7, 128)    102528      ['re_lu_225[0][0]']
#
#  batch_normalization_226 (Batch  (None, 7, 7, 128)   512         ['conv2d_225[0][0]']
#  Normalization)
#
#  re_lu_226 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_226[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_226[0][0]']
#
#  concatenate_109 (Concatenate)  (None, 7, 7, 832)    0           ['conv2d_226[0][0]',
#                                                                   'concatenate_108[0][0]']
#
#  batch_normalization_227 (Batch  (None, 7, 7, 832)   3328        ['concatenate_109[0][0]']
#  Normalization)
#
#  re_lu_227 (ReLU)               (None, 7, 7, 832)    0           ['batch_normalization_227[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 7, 7, 128)    106624      ['re_lu_227[0][0]']
#
#  batch_normalization_228 (Batch  (None, 7, 7, 128)   512         ['conv2d_227[0][0]']
#  Normalization)
#
#  re_lu_228 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_228[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_228[0][0]']
#
#  concatenate_110 (Concatenate)  (None, 7, 7, 864)    0           ['conv2d_228[0][0]',
#                                                                   'concatenate_109[0][0]']
#
#  batch_normalization_229 (Batch  (None, 7, 7, 864)   3456        ['concatenate_110[0][0]']
#  Normalization)
#
#  re_lu_229 (ReLU)               (None, 7, 7, 864)    0           ['batch_normalization_229[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 7, 7, 128)    110720      ['re_lu_229[0][0]']
#
#  batch_normalization_230 (Batch  (None, 7, 7, 128)   512         ['conv2d_229[0][0]']
#  Normalization)
#
#  re_lu_230 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_230[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_230[0][0]']
#
#  concatenate_111 (Concatenate)  (None, 7, 7, 896)    0           ['conv2d_230[0][0]',
#                                                                   'concatenate_110[0][0]']
#
#  batch_normalization_231 (Batch  (None, 7, 7, 896)   3584        ['concatenate_111[0][0]']
#  Normalization)
#
#  re_lu_231 (ReLU)               (None, 7, 7, 896)    0           ['batch_normalization_231[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 7, 7, 128)    114816      ['re_lu_231[0][0]']
#
#  batch_normalization_232 (Batch  (None, 7, 7, 128)   512         ['conv2d_231[0][0]']
#  Normalization)
#
#  re_lu_232 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_232[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_232[0][0]']
#
#  concatenate_112 (Concatenate)  (None, 7, 7, 928)    0           ['conv2d_232[0][0]',
#                                                                   'concatenate_111[0][0]']
#
#  batch_normalization_233 (Batch  (None, 7, 7, 928)   3712        ['concatenate_112[0][0]']
#  Normalization)
#
#  re_lu_233 (ReLU)               (None, 7, 7, 928)    0           ['batch_normalization_233[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 7, 7, 128)    118912      ['re_lu_233[0][0]']
#  batch_normalization_234 (Batch  (None, 7, 7, 128)   512         ['conv2d_233[0][0]']
#  Normalization)
#
#  re_lu_234 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_234[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_234[0][0]']
#
#  concatenate_113 (Concatenate)  (None, 7, 7, 960)    0           ['conv2d_234[0][0]',
#                                                                   'concatenate_112[0][0]']
#
#  batch_normalization_235 (Batch  (None, 7, 7, 960)   3840        ['concatenate_113[0][0]']
#  Normalization)
#
#  re_lu_235 (ReLU)               (None, 7, 7, 960)    0           ['batch_normalization_235[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 7, 7, 128)    123008      ['re_lu_235[0][0]']
#
#  batch_normalization_236 (Batch  (None, 7, 7, 128)   512         ['conv2d_235[0][0]']
#  Normalization)
#
#  re_lu_236 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_236[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_236[0][0]']
#
#  concatenate_114 (Concatenate)  (None, 7, 7, 992)    0           ['conv2d_236[0][0]',
#                                                                   'concatenate_113[0][0]']
#
#  batch_normalization_237 (Batch  (None, 7, 7, 992)   3968        ['concatenate_114[0][0]']
#  Normalization)
#
#  re_lu_237 (ReLU)               (None, 7, 7, 992)    0           ['batch_normalization_237[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 7, 7, 128)    127104      ['re_lu_237[0][0]']
#
#  batch_normalization_238 (Batch  (None, 7, 7, 128)   512         ['conv2d_237[0][0]']
#  Normalization)
#
#  re_lu_238 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_238[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_238[0][0]']
#
#  concatenate_115 (Concatenate)  (None, 7, 7, 1024)   0           ['conv2d_238[0][0]',
#                                                                   'concatenate_114[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1024)        0           ['concatenate_115[0][0]']
#  obalAveragePooling2D)
#
# ==================================================================================================
# Total params: 7,043,648
# Trainable params: 6,962,048
# Non-trainable params: 81,600
# __________________________________________________________________________________________________

# %% [markdown]
# #### Import DenseNet121() from tf.keras.applications.densenet. You can compare both cases!!!

# %%
densenet121 = tf.keras.applications.densenet.DenseNet121(
    include_top=False,
    input_shape= (224, 224, 3),
    weights='imagenet'
)
densenet121.summary()
# Out:
# Model: "densenet121"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_3[0][0]']
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 56, 56, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 56, 56, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 56, 56, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 56, 56, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 56, 56, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 56, 56, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 56, 56, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 56, 56, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 56, 56, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 56, 56, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 56, 56, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 56, 56, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 56, 56, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 56, 56, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 56, 56, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 56, 56, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 56, 56, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 56, 56, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 56, 56, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 28, 28, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 28, 28, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 28, 28, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#  conv3_block2_0_relu (Activatio  (None, 28, 28, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 28, 28, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 28, 28, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 28, 28, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 28, 28, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 28, 28, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 28, 28, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 28, 28, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 28, 28, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 28, 28, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 28, 28, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 28, 28, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 28, 28, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 28, 28, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 28, 28, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 28, 28, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 28, 28, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 28, 28, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 28, 28, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 28, 28, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 28, 28, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 28, 28, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 28, 28, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 28, 28, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 28, 28, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 28, 28, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 28, 28, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 28, 28, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 28, 28, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 28, 28, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 28, 28, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 28, 28, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 28, 28, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 28, 28, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 28, 28, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 28, 28, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 28, 28, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 28, 28, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 28, 28, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 14, 14, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 14, 14, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 14, 14, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 14, 14, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block2_1_relu[0][0]']
#  conv4_block2_concat (Concatena  (None, 14, 14, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 14, 14, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 14, 14, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 14, 14, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 14, 14, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 14, 14, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 14, 14, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 14, 14, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 14, 14, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 14, 14, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 14, 14, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 14, 14, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block6_1_bn[0][0]']
#  n)
# ...
#  conv5_block8_concat (Concatena  (None, 7, 7, 768)   0           ['conv5_block7_concat[0][0]',
#  te)                                                              'conv5_block8_2_conv[0][0]']
#
#  conv5_block9_0_bn (BatchNormal  (None, 7, 7, 768)   3072        ['conv5_block8_concat[0][0]']
#  ization)
#
#  conv5_block9_0_relu (Activatio  (None, 7, 7, 768)   0           ['conv5_block9_0_bn[0][0]']
#  n)
#
#  conv5_block9_1_conv (Conv2D)   (None, 7, 7, 128)    98304       ['conv5_block9_0_relu[0][0]']
#
#  conv5_block9_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv5_block9_1_conv[0][0]']
#  ization)
#
#  conv5_block9_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv5_block9_1_bn[0][0]']
#  n)
#
#  conv5_block9_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv5_block9_1_relu[0][0]']
#
#  conv5_block9_concat (Concatena  (None, 7, 7, 800)   0           ['conv5_block8_concat[0][0]',
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 7, 7, 800)   3200        ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 7, 7, 800)   0           ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 7, 7, 128)    102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 7, 7, 832)   0           ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 7, 7, 832)   3328        ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 7, 7, 832)   0           ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 7, 7, 128)    106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 7, 7, 864)   0           ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 7, 7, 864)   3456        ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 7, 7, 864)   0           ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 7, 7, 128)    110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 7, 7, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 7, 7, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 7, 7, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 7, 7, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 7, 7, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 7, 7, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 7, 7, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 7, 7, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 7, 7, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 7, 7, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 7, 7, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 7, 7, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 7, 7, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 7, 7, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 7, 7, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 7, 7, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 7, 7, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 7, 7, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 7, 7, 1024)   0           ['bn[0][0]']
#
# ==================================================================================================
# Total params: 7,037,504
# Trainable params: 6,953,856
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %%
densenet201 = DenseNet(input_shape=(224, 224, 3), n_classes=10).DenseNet201().summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_11 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_zeropadding (ZeroPadding  (None, 230, 230, 3)  0          ['input_11[0][0]']
#  2D)
#
#  conv1 (Conv2D)                 (None, 112, 112, 64  9472        ['conv1_zeropadding[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1[0][0]']
#                                 )
#
#  relu1 (Activation)             (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_zeropadding (ZeroPadding  (None, 114, 114, 64  0          ['relu1[0][0]']
#  2D)                            )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['pool1_zeropadding[0][0]']
#
#  batch_normalization_864 (Batch  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  Normalization)
#
#  re_lu_864 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_864[0][0]']
#
#  conv2d_864 (Conv2D)            (None, 56, 56, 128)  8320        ['re_lu_864[0][0]']
#
#  batch_normalization_865 (Batch  (None, 56, 56, 128)  512        ['conv2d_864[0][0]']
#  Normalization)
#
#  re_lu_865 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_865[0][0]']
#
#  conv2d_865 (Conv2D)            (None, 56, 56, 32)   36896       ['re_lu_865[0][0]']
#
#  concatenate_420 (Concatenate)  (None, 56, 56, 96)   0           ['conv2d_865[0][0]',
#                                                                   'pool1[0][0]']
#
#  batch_normalization_866 (Batch  (None, 56, 56, 96)  384         ['concatenate_420[0][0]']
#  Normalization)
#
#  re_lu_866 (ReLU)               (None, 56, 56, 96)   0           ['batch_normalization_866[0][0]']
#
#  conv2d_866 (Conv2D)            (None, 56, 56, 128)  12416       ['re_lu_866[0][0]']
#
#  batch_normalization_867 (Batch  (None, 56, 56, 128)  512        ['conv2d_866[0][0]']
#  Normalization)
#
#  re_lu_867 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_867[0][0]']
#
#  conv2d_867 (Conv2D)            (None, 56, 56, 32)   36896       ['re_lu_867[0][0]']
#
#  concatenate_421 (Concatenate)  (None, 56, 56, 128)  0           ['conv2d_867[0][0]',
#                                                                   'concatenate_420[0][0]']
#
#  batch_normalization_868 (Batch  (None, 56, 56, 128)  512        ['concatenate_421[0][0]']
#  Normalization)
#
#  re_lu_868 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_868[0][0]']
#
#  conv2d_868 (Conv2D)            (None, 56, 56, 128)  16512       ['re_lu_868[0][0]']
#
#  batch_normalization_869 (Batch  (None, 56, 56, 128)  512        ['conv2d_868[0][0]']
#  Normalization)
#
#  re_lu_869 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_869[0][0]']
#
#  conv2d_869 (Conv2D)            (None, 56, 56, 32)   36896       ['re_lu_869[0][0]']
#
#  concatenate_422 (Concatenate)  (None, 56, 56, 160)  0           ['conv2d_869[0][0]',
#                                                                   'concatenate_421[0][0]']
#
#  batch_normalization_870 (Batch  (None, 56, 56, 160)  640        ['concatenate_422[0][0]']
#  Normalization)
#
#  re_lu_870 (ReLU)               (None, 56, 56, 160)  0           ['batch_normalization_870[0][0]']
#
#  conv2d_870 (Conv2D)            (None, 56, 56, 128)  20608       ['re_lu_870[0][0]']
#
#  batch_normalization_871 (Batch  (None, 56, 56, 128)  512        ['conv2d_870[0][0]']
#  Normalization)
#
#  re_lu_871 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_871[0][0]']
#
#  conv2d_871 (Conv2D)            (None, 56, 56, 32)   36896       ['re_lu_871[0][0]']
#
#  concatenate_423 (Concatenate)  (None, 56, 56, 192)  0           ['conv2d_871[0][0]',
#                                                                   'concatenate_422[0][0]']
#
#  batch_normalization_872 (Batch  (None, 56, 56, 192)  768        ['concatenate_423[0][0]']
#  Normalization)
#
#  re_lu_872 (ReLU)               (None, 56, 56, 192)  0           ['batch_normalization_872[0][0]']
#
#  conv2d_872 (Conv2D)            (None, 56, 56, 128)  24704       ['re_lu_872[0][0]']
#
#  batch_normalization_873 (Batch  (None, 56, 56, 128)  512        ['conv2d_872[0][0]']
#  Normalization)
#
#  re_lu_873 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_873[0][0]']
#
#  conv2d_873 (Conv2D)            (None, 56, 56, 32)   36896       ['re_lu_873[0][0]']
#
#  concatenate_424 (Concatenate)  (None, 56, 56, 224)  0           ['conv2d_873[0][0]',
#                                                                   'concatenate_423[0][0]']
#
#  batch_normalization_874 (Batch  (None, 56, 56, 224)  896        ['concatenate_424[0][0]']
#  Normalization)
#
#  re_lu_874 (ReLU)               (None, 56, 56, 224)  0           ['batch_normalization_874[0][0]']
#
#  conv2d_874 (Conv2D)            (None, 56, 56, 128)  28800       ['re_lu_874[0][0]']
#
#  batch_normalization_875 (Batch  (None, 56, 56, 128)  512        ['conv2d_874[0][0]']
#  Normalization)
#
#  re_lu_875 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_875[0][0]']
#
#  conv2d_875 (Conv2D)            (None, 56, 56, 32)   36896       ['re_lu_875[0][0]']
#
#  concatenate_425 (Concatenate)  (None, 56, 56, 256)  0           ['conv2d_875[0][0]',
#                                                                   'concatenate_424[0][0]']
#
#  batch_normalization_876 (Batch  (None, 56, 56, 256)  1024       ['concatenate_425[0][0]']
#  Normalization)
#
#  re_lu_876 (ReLU)               (None, 56, 56, 256)  0           ['batch_normalization_876[0][0]']
#
#  conv2d_876 (Conv2D)            (None, 56, 56, 128)  32896       ['re_lu_876[0][0]']
#
#  average_pooling2d_24 (AverageP  (None, 28, 28, 128)  0          ['conv2d_876[0][0]']
#  ooling2D)
#
#  batch_normalization_877 (Batch  (None, 28, 28, 128)  512        ['average_pooling2d_24[0][0]']
#  Normalization)
#
#  re_lu_877 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_877[0][0]']
#
#  conv2d_877 (Conv2D)            (None, 28, 28, 128)  16512       ['re_lu_877[0][0]']
#
#  batch_normalization_878 (Batch  (None, 28, 28, 128)  512        ['conv2d_877[0][0]']
#  Normalization)
#
#  re_lu_878 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_878[0][0]']
#
#  conv2d_878 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_878[0][0]']
#
#  concatenate_426 (Concatenate)  (None, 28, 28, 160)  0           ['conv2d_878[0][0]',
#                                                                   'average_pooling2d_24[0][0]']
#
#  batch_normalization_879 (Batch  (None, 28, 28, 160)  640        ['concatenate_426[0][0]']
#  Normalization)
#
#  re_lu_879 (ReLU)               (None, 28, 28, 160)  0           ['batch_normalization_879[0][0]']
#
#  conv2d_879 (Conv2D)            (None, 28, 28, 128)  20608       ['re_lu_879[0][0]']
#
#  batch_normalization_880 (Batch  (None, 28, 28, 128)  512        ['conv2d_879[0][0]']
#  Normalization)
#
#  re_lu_880 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_880[0][0]']
#
#  conv2d_880 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_880[0][0]']
#  concatenate_427 (Concatenate)  (None, 28, 28, 192)  0           ['conv2d_880[0][0]',
#                                                                   'concatenate_426[0][0]']
#
#  batch_normalization_881 (Batch  (None, 28, 28, 192)  768        ['concatenate_427[0][0]']
#  Normalization)
#
#  re_lu_881 (ReLU)               (None, 28, 28, 192)  0           ['batch_normalization_881[0][0]']
#
#  conv2d_881 (Conv2D)            (None, 28, 28, 128)  24704       ['re_lu_881[0][0]']
#
#  batch_normalization_882 (Batch  (None, 28, 28, 128)  512        ['conv2d_881[0][0]']
#  Normalization)
#
#  re_lu_882 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_882[0][0]']
#
#  conv2d_882 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_882[0][0]']
#
#  concatenate_428 (Concatenate)  (None, 28, 28, 224)  0           ['conv2d_882[0][0]',
#                                                                   'concatenate_427[0][0]']
#
#  batch_normalization_883 (Batch  (None, 28, 28, 224)  896        ['concatenate_428[0][0]']
#  Normalization)
#
#  re_lu_883 (ReLU)               (None, 28, 28, 224)  0           ['batch_normalization_883[0][0]']
#
#  conv2d_883 (Conv2D)            (None, 28, 28, 128)  28800       ['re_lu_883[0][0]']
#
#  batch_normalization_884 (Batch  (None, 28, 28, 128)  512        ['conv2d_883[0][0]']
#  Normalization)
#
#  re_lu_884 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_884[0][0]']
#
#  conv2d_884 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_884[0][0]']
#
#  concatenate_429 (Concatenate)  (None, 28, 28, 256)  0           ['conv2d_884[0][0]',
#                                                                   'concatenate_428[0][0]']
#
#  batch_normalization_885 (Batch  (None, 28, 28, 256)  1024       ['concatenate_429[0][0]']
#  Normalization)
#
#  re_lu_885 (ReLU)               (None, 28, 28, 256)  0           ['batch_normalization_885[0][0]']
#
#  conv2d_885 (Conv2D)            (None, 28, 28, 128)  32896       ['re_lu_885[0][0]']
#
#  batch_normalization_886 (Batch  (None, 28, 28, 128)  512        ['conv2d_885[0][0]']
#  Normalization)
#
#  re_lu_886 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_886[0][0]']
#
#  conv2d_886 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_886[0][0]']
#
#  concatenate_430 (Concatenate)  (None, 28, 28, 288)  0           ['conv2d_886[0][0]',
#                                                                   'concatenate_429[0][0]']
#
#  batch_normalization_887 (Batch  (None, 28, 28, 288)  1152       ['concatenate_430[0][0]']
#  Normalization)
#
#  re_lu_887 (ReLU)               (None, 28, 28, 288)  0           ['batch_normalization_887[0][0]']
#
#  conv2d_887 (Conv2D)            (None, 28, 28, 128)  36992       ['re_lu_887[0][0]']
#
#  batch_normalization_888 (Batch  (None, 28, 28, 128)  512        ['conv2d_887[0][0]']
#  Normalization)
#
#  re_lu_888 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_888[0][0]']
#
#  conv2d_888 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_888[0][0]']
#
#  concatenate_431 (Concatenate)  (None, 28, 28, 320)  0           ['conv2d_888[0][0]',
#                                                                   'concatenate_430[0][0]']
#
#  batch_normalization_889 (Batch  (None, 28, 28, 320)  1280       ['concatenate_431[0][0]']
#  Normalization)
#
#  re_lu_889 (ReLU)               (None, 28, 28, 320)  0           ['batch_normalization_889[0][0]']
#
#  conv2d_889 (Conv2D)            (None, 28, 28, 128)  41088       ['re_lu_889[0][0]']
#
#  batch_normalization_890 (Batch  (None, 28, 28, 128)  512        ['conv2d_889[0][0]']
#  Normalization)
#
#  re_lu_890 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_890[0][0]']
#  conv2d_890 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_890[0][0]']
#
#  concatenate_432 (Concatenate)  (None, 28, 28, 352)  0           ['conv2d_890[0][0]',
#                                                                   'concatenate_431[0][0]']
#
#  batch_normalization_891 (Batch  (None, 28, 28, 352)  1408       ['concatenate_432[0][0]']
#  Normalization)
#
#  re_lu_891 (ReLU)               (None, 28, 28, 352)  0           ['batch_normalization_891[0][0]']
#
#  conv2d_891 (Conv2D)            (None, 28, 28, 128)  45184       ['re_lu_891[0][0]']
#
#  batch_normalization_892 (Batch  (None, 28, 28, 128)  512        ['conv2d_891[0][0]']
#  Normalization)
#
#  re_lu_892 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_892[0][0]']
#
#  conv2d_892 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_892[0][0]']
#
#  concatenate_433 (Concatenate)  (None, 28, 28, 384)  0           ['conv2d_892[0][0]',
#                                                                   'concatenate_432[0][0]']
#
#  batch_normalization_893 (Batch  (None, 28, 28, 384)  1536       ['concatenate_433[0][0]']
#  Normalization)
#
#  re_lu_893 (ReLU)               (None, 28, 28, 384)  0           ['batch_normalization_893[0][0]']
#
#  conv2d_893 (Conv2D)            (None, 28, 28, 128)  49280       ['re_lu_893[0][0]']
#
#  batch_normalization_894 (Batch  (None, 28, 28, 128)  512        ['conv2d_893[0][0]']
#  Normalization)
#
#  re_lu_894 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_894[0][0]']
#
#  conv2d_894 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_894[0][0]']
#
#  concatenate_434 (Concatenate)  (None, 28, 28, 416)  0           ['conv2d_894[0][0]',
#                                                                   'concatenate_433[0][0]']
#
#  batch_normalization_895 (Batch  (None, 28, 28, 416)  1664       ['concatenate_434[0][0]']
#  Normalization)
#
#  re_lu_895 (ReLU)               (None, 28, 28, 416)  0           ['batch_normalization_895[0][0]']
#
#  conv2d_895 (Conv2D)            (None, 28, 28, 128)  53376       ['re_lu_895[0][0]']
#
#  batch_normalization_896 (Batch  (None, 28, 28, 128)  512        ['conv2d_895[0][0]']
#  Normalization)
#
#  re_lu_896 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_896[0][0]']
#
#  conv2d_896 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_896[0][0]']
#
#  concatenate_435 (Concatenate)  (None, 28, 28, 448)  0           ['conv2d_896[0][0]',
#                                                                   'concatenate_434[0][0]']
#
#  batch_normalization_897 (Batch  (None, 28, 28, 448)  1792       ['concatenate_435[0][0]']
#  Normalization)
#
#  re_lu_897 (ReLU)               (None, 28, 28, 448)  0           ['batch_normalization_897[0][0]']
#
#  conv2d_897 (Conv2D)            (None, 28, 28, 128)  57472       ['re_lu_897[0][0]']
#
#  batch_normalization_898 (Batch  (None, 28, 28, 128)  512        ['conv2d_897[0][0]']
#  Normalization)
#
#  re_lu_898 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_898[0][0]']
#
#  conv2d_898 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_898[0][0]']
#
#  concatenate_436 (Concatenate)  (None, 28, 28, 480)  0           ['conv2d_898[0][0]',
#                                                                   'concatenate_435[0][0]']
#
#  batch_normalization_899 (Batch  (None, 28, 28, 480)  1920       ['concatenate_436[0][0]']
#  Normalization)
#
#  re_lu_899 (ReLU)               (None, 28, 28, 480)  0           ['batch_normalization_899[0][0]']
#
#  conv2d_899 (Conv2D)            (None, 28, 28, 128)  61568       ['re_lu_899[0][0]']
#
#  batch_normalization_900 (Batch  (None, 28, 28, 128)  512        ['conv2d_899[0][0]']
#  Normalization)
#  re_lu_900 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_900[0][0]']
#
#  conv2d_900 (Conv2D)            (None, 28, 28, 32)   36896       ['re_lu_900[0][0]']
#
#  concatenate_437 (Concatenate)  (None, 28, 28, 512)  0           ['conv2d_900[0][0]',
#                                                                   'concatenate_436[0][0]']
#
#  batch_normalization_901 (Batch  (None, 28, 28, 512)  2048       ['concatenate_437[0][0]']
#  Normalization)
#
#  re_lu_901 (ReLU)               (None, 28, 28, 512)  0           ['batch_normalization_901[0][0]']
#
#  conv2d_901 (Conv2D)            (None, 28, 28, 256)  131328      ['re_lu_901[0][0]']
#
#  average_pooling2d_25 (AverageP  (None, 14, 14, 256)  0          ['conv2d_901[0][0]']
#  ooling2D)
#
#  batch_normalization_902 (Batch  (None, 14, 14, 256)  1024       ['average_pooling2d_25[0][0]']
#  Normalization)
#
#  re_lu_902 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_902[0][0]']
#
#  conv2d_902 (Conv2D)            (None, 14, 14, 128)  32896       ['re_lu_902[0][0]']
#
#  batch_normalization_903 (Batch  (None, 14, 14, 128)  512        ['conv2d_902[0][0]']
#  Normalization)
#
#  re_lu_903 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_903[0][0]']
#
#  conv2d_903 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_903[0][0]']
#
#  concatenate_438 (Concatenate)  (None, 14, 14, 288)  0           ['conv2d_903[0][0]',
#                                                                   'average_pooling2d_25[0][0]']
#
#  batch_normalization_904 (Batch  (None, 14, 14, 288)  1152       ['concatenate_438[0][0]']
#  Normalization)
#
#  re_lu_904 (ReLU)               (None, 14, 14, 288)  0           ['batch_normalization_904[0][0]']
#
#  conv2d_904 (Conv2D)            (None, 14, 14, 128)  36992       ['re_lu_904[0][0]']
#
#  batch_normalization_905 (Batch  (None, 14, 14, 128)  512        ['conv2d_904[0][0]']
#  Normalization)
#
#  re_lu_905 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_905[0][0]']
#
#  conv2d_905 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_905[0][0]']
#
#  concatenate_439 (Concatenate)  (None, 14, 14, 320)  0           ['conv2d_905[0][0]',
#                                                                   'concatenate_438[0][0]']
#
#  batch_normalization_906 (Batch  (None, 14, 14, 320)  1280       ['concatenate_439[0][0]']
#  Normalization)
#
#  re_lu_906 (ReLU)               (None, 14, 14, 320)  0           ['batch_normalization_906[0][0]']
#
#  conv2d_906 (Conv2D)            (None, 14, 14, 128)  41088       ['re_lu_906[0][0]']
#
#  batch_normalization_907 (Batch  (None, 14, 14, 128)  512        ['conv2d_906[0][0]']
#  Normalization)
#
#  re_lu_907 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_907[0][0]']
#
#  conv2d_907 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_907[0][0]']
#
#  concatenate_440 (Concatenate)  (None, 14, 14, 352)  0           ['conv2d_907[0][0]',
#                                                                   'concatenate_439[0][0]']
#
#  batch_normalization_908 (Batch  (None, 14, 14, 352)  1408       ['concatenate_440[0][0]']
#  Normalization)
#
#  re_lu_908 (ReLU)               (None, 14, 14, 352)  0           ['batch_normalization_908[0][0]']
#
#  conv2d_908 (Conv2D)            (None, 14, 14, 128)  45184       ['re_lu_908[0][0]']
#
#  batch_normalization_909 (Batch  (None, 14, 14, 128)  512        ['conv2d_908[0][0]']
#  Normalization)
#
#  re_lu_909 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_909[0][0]']
#
#  conv2d_909 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_909[0][0]']
#
#  concatenate_441 (Concatenate)  (None, 14, 14, 384)  0           ['conv2d_909[0][0]',
#                                                                   'concatenate_440[0][0]']
#
#  batch_normalization_910 (Batch  (None, 14, 14, 384)  1536       ['concatenate_441[0][0]']
#  Normalization)
#
#  re_lu_910 (ReLU)               (None, 14, 14, 384)  0           ['batch_normalization_910[0][0]']
#
#  conv2d_910 (Conv2D)            (None, 14, 14, 128)  49280       ['re_lu_910[0][0]']
#
#  batch_normalization_911 (Batch  (None, 14, 14, 128)  512        ['conv2d_910[0][0]']
#  Normalization)
#
#  re_lu_911 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_911[0][0]']
#
#  conv2d_911 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_911[0][0]']
#
#  concatenate_442 (Concatenate)  (None, 14, 14, 416)  0           ['conv2d_911[0][0]',
#                                                                   'concatenate_441[0][0]']
#
#  batch_normalization_912 (Batch  (None, 14, 14, 416)  1664       ['concatenate_442[0][0]']
#  Normalization)
#
#  re_lu_912 (ReLU)               (None, 14, 14, 416)  0           ['batch_normalization_912[0][0]']
#
#  conv2d_912 (Conv2D)            (None, 14, 14, 128)  53376       ['re_lu_912[0][0]']
#
#  batch_normalization_913 (Batch  (None, 14, 14, 128)  512        ['conv2d_912[0][0]']
#  Normalization)
#
#  re_lu_913 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_913[0][0]']
#
#  conv2d_913 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_913[0][0]']
#
#  concatenate_443 (Concatenate)  (None, 14, 14, 448)  0           ['conv2d_913[0][0]',
#                                                                   'concatenate_442[0][0]']
#
#  batch_normalization_914 (Batch  (None, 14, 14, 448)  1792       ['concatenate_443[0][0]']
#  Normalization)
#
#  re_lu_914 (ReLU)               (None, 14, 14, 448)  0           ['batch_normalization_914[0][0]']
#
#  conv2d_914 (Conv2D)            (None, 14, 14, 128)  57472       ['re_lu_914[0][0]']
#
#  batch_normalization_915 (Batch  (None, 14, 14, 128)  512        ['conv2d_914[0][0]']
#  Normalization)
#
#  re_lu_915 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_915[0][0]']
#
#  conv2d_915 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_915[0][0]']
#
#  concatenate_444 (Concatenate)  (None, 14, 14, 480)  0           ['conv2d_915[0][0]',
#                                                                   'concatenate_443[0][0]']
#
#  batch_normalization_916 (Batch  (None, 14, 14, 480)  1920       ['concatenate_444[0][0]']
#  Normalization)
#
#  re_lu_916 (ReLU)               (None, 14, 14, 480)  0           ['batch_normalization_916[0][0]']
#
#  conv2d_916 (Conv2D)            (None, 14, 14, 128)  61568       ['re_lu_916[0][0]']
#
#  batch_normalization_917 (Batch  (None, 14, 14, 128)  512        ['conv2d_916[0][0]']
#  Normalization)
#
#  re_lu_917 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_917[0][0]']
#
#  conv2d_917 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_917[0][0]']
#
#  concatenate_445 (Concatenate)  (None, 14, 14, 512)  0           ['conv2d_917[0][0]',
#                                                                   'concatenate_444[0][0]']
#
#  batch_normalization_918 (Batch  (None, 14, 14, 512)  2048       ['concatenate_445[0][0]']
#  Normalization)
#
#  re_lu_918 (ReLU)               (None, 14, 14, 512)  0           ['batch_normalization_918[0][0]']
# ...
#
#  concatenate_509 (Concatenate)  (None, 7, 7, 1664)   0           ['conv2d_1046[0][0]',
#                                                                   'concatenate_508[0][0]']
#
#  batch_normalization_1047 (Batc  (None, 7, 7, 1664)  6656        ['concatenate_509[0][0]']
#  hNormalization)
#
#  re_lu_1047 (ReLU)              (None, 7, 7, 1664)   0           ['batch_normalization_1047[0][0]'
#                                                                  ]
#
#  conv2d_1047 (Conv2D)           (None, 7, 7, 128)    213120      ['re_lu_1047[0][0]']
#
#  batch_normalization_1048 (Batc  (None, 7, 7, 128)   512         ['conv2d_1047[0][0]']
#  hNormalization)
#
#  re_lu_1048 (ReLU)              (None, 7, 7, 128)    0           ['batch_normalization_1048[0][0]'
#                                                                  ]
#
#  conv2d_1048 (Conv2D)           (None, 7, 7, 32)     36896       ['re_lu_1048[0][0]']
#
#  concatenate_510 (Concatenate)  (None, 7, 7, 1696)   0           ['conv2d_1048[0][0]',
#                                                                   'concatenate_509[0][0]']
#
#  batch_normalization_1049 (Batc  (None, 7, 7, 1696)  6784        ['concatenate_510[0][0]']
#  hNormalization)
#
#  re_lu_1049 (ReLU)              (None, 7, 7, 1696)   0           ['batch_normalization_1049[0][0]'
#                                                                  ]
#
#  conv2d_1049 (Conv2D)           (None, 7, 7, 128)    217216      ['re_lu_1049[0][0]']
#
#  batch_normalization_1050 (Batc  (None, 7, 7, 128)   512         ['conv2d_1049[0][0]']
#  hNormalization)
#
#  re_lu_1050 (ReLU)              (None, 7, 7, 128)    0           ['batch_normalization_1050[0][0]'
#                                                                  ]
#
#  conv2d_1050 (Conv2D)           (None, 7, 7, 32)     36896       ['re_lu_1050[0][0]']
#
#  concatenate_511 (Concatenate)  (None, 7, 7, 1728)   0           ['conv2d_1050[0][0]',
#                                                                   'concatenate_510[0][0]']
#
#  batch_normalization_1051 (Batc  (None, 7, 7, 1728)  6912        ['concatenate_511[0][0]']
#  hNormalization)
#
#  re_lu_1051 (ReLU)              (None, 7, 7, 1728)   0           ['batch_normalization_1051[0][0]'
#                                                                  ]
#
#  conv2d_1051 (Conv2D)           (None, 7, 7, 128)    221312      ['re_lu_1051[0][0]']
#
#  batch_normalization_1052 (Batc  (None, 7, 7, 128)   512         ['conv2d_1051[0][0]']
#  hNormalization)
#
#  re_lu_1052 (ReLU)              (None, 7, 7, 128)    0           ['batch_normalization_1052[0][0]'
#                                                                  ]
#
#  conv2d_1052 (Conv2D)           (None, 7, 7, 32)     36896       ['re_lu_1052[0][0]']
#
#  concatenate_512 (Concatenate)  (None, 7, 7, 1760)   0           ['conv2d_1052[0][0]',
#                                                                   'concatenate_511[0][0]']
#
#  batch_normalization_1053 (Batc  (None, 7, 7, 1760)  7040        ['concatenate_512[0][0]']
#  hNormalization)
#
#  re_lu_1053 (ReLU)              (None, 7, 7, 1760)   0           ['batch_normalization_1053[0][0]'
#                                                                  ]
#
#  conv2d_1053 (Conv2D)           (None, 7, 7, 128)    225408      ['re_lu_1053[0][0]']
#
#  batch_normalization_1054 (Batc  (None, 7, 7, 128)   512         ['conv2d_1053[0][0]']
#  hNormalization)
#
#  re_lu_1054 (ReLU)              (None, 7, 7, 128)    0           ['batch_normalization_1054[0][0]'
#                                                                  ]
#
#  conv2d_1054 (Conv2D)           (None, 7, 7, 32)     36896       ['re_lu_1054[0][0]']
#
#  concatenate_513 (Concatenate)  (None, 7, 7, 1792)   0           ['conv2d_1054[0][0]',
#                                                                   'concatenate_512[0][0]']
#
#  batch_normalization_1055 (Batc  (None, 7, 7, 1792)  7168        ['concatenate_513[0][0]']
#  hNormalization)
#
#  re_lu_1055 (ReLU)              (None, 7, 7, 1792)   0           ['batch_normalization_1055[0][0]'
#                                                                  ]
#
#  conv2d_1055 (Conv2D)           (None, 7, 7, 128)    229504      ['re_lu_1055[0][0]']
#
#  batch_normalization_1056 (Batc  (None, 7, 7, 128)   512         ['conv2d_1055[0][0]']
#  hNormalization)
#
#  re_lu_1056 (ReLU)              (None, 7, 7, 128)    0           ['batch_normalization_1056[0][0]'
#                                                                  ]
#
#  conv2d_1056 (Conv2D)           (None, 7, 7, 32)     36896       ['re_lu_1056[0][0]']
#
#  concatenate_514 (Concatenate)  (None, 7, 7, 1824)   0           ['conv2d_1056[0][0]',
#                                                                   'concatenate_513[0][0]']
#
#  batch_normalization_1057 (Batc  (None, 7, 7, 1824)  7296        ['concatenate_514[0][0]']
#  hNormalization)
#
#  re_lu_1057 (ReLU)              (None, 7, 7, 1824)   0           ['batch_normalization_1057[0][0]'
#                                                                  ]
#
#  conv2d_1057 (Conv2D)           (None, 7, 7, 128)    233600      ['re_lu_1057[0][0]']
#
#  batch_normalization_1058 (Batc  (None, 7, 7, 128)   512         ['conv2d_1057[0][0]']
#  hNormalization)
#
#  re_lu_1058 (ReLU)              (None, 7, 7, 128)    0           ['batch_normalization_1058[0][0]'
#                                                                  ]
#
#  conv2d_1058 (Conv2D)           (None, 7, 7, 32)     36896       ['re_lu_1058[0][0]']
#
#  concatenate_515 (Concatenate)  (None, 7, 7, 1856)   0           ['conv2d_1058[0][0]',
#                                                                   'concatenate_514[0][0]']
#
#  batch_normalization_1059 (Batc  (None, 7, 7, 1856)  7424        ['concatenate_515[0][0]']
#  hNormalization)
#
#  re_lu_1059 (ReLU)              (None, 7, 7, 1856)   0           ['batch_normalization_1059[0][0]'
#                                                                  ]
#
#  conv2d_1059 (Conv2D)           (None, 7, 7, 128)    237696      ['re_lu_1059[0][0]']
#
#  batch_normalization_1060 (Batc  (None, 7, 7, 128)   512         ['conv2d_1059[0][0]']
#  hNormalization)
#
#  re_lu_1060 (ReLU)              (None, 7, 7, 128)    0           ['batch_normalization_1060[0][0]'
#                                                                  ]
#
#  conv2d_1060 (Conv2D)           (None, 7, 7, 32)     36896       ['re_lu_1060[0][0]']
#
#  concatenate_516 (Concatenate)  (None, 7, 7, 1888)   0           ['conv2d_1060[0][0]',
#                                                                   'concatenate_515[0][0]']
#
#  batch_normalization_1061 (Batc  (None, 7, 7, 1888)  7552        ['concatenate_516[0][0]']
#  hNormalization)
#
#  re_lu_1061 (ReLU)              (None, 7, 7, 1888)   0           ['batch_normalization_1061[0][0]'
#                                                                  ]
#
#  conv2d_1061 (Conv2D)           (None, 7, 7, 128)    241792      ['re_lu_1061[0][0]']
#
#  batch_normalization_1062 (Batc  (None, 7, 7, 128)   512         ['conv2d_1061[0][0]']
#  hNormalization)
#
#  re_lu_1062 (ReLU)              (None, 7, 7, 128)    0           ['batch_normalization_1062[0][0]'
#                                                                  ]
#
#  conv2d_1062 (Conv2D)           (None, 7, 7, 32)     36896       ['re_lu_1062[0][0]']
#
#  concatenate_517 (Concatenate)  (None, 7, 7, 1920)   0           ['conv2d_1062[0][0]',
#                                                                   'concatenate_516[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 1920)        0           ['concatenate_517[0][0]']
#  obalAveragePooling2D)
#
# ==================================================================================================
# Total params: 18,331,328
# Trainable params: 18,106,112
# Non-trainable params: 225,216
# __________________________________________________________________________________________________

# %%
densenet201 = tf.keras.applications.densenet.DenseNet201(
    include_top=False,
    input_shape= (224, 224, 3),
    weights='imagenet'
)
densenet201.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 28s 0us/step
# Model: "densenet201"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_6 (ZeroPadding2  (None, 230, 230, 3)  0          ['input_9[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d_6[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_7 (ZeroPadding2  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['zero_padding2d_7[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 56, 56, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 56, 56, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 56, 56, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 56, 56, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 56, 56, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 56, 56, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 56, 56, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 56, 56, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 56, 56, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 56, 56, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 56, 56, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 56, 56, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 56, 56, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 56, 56, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 56, 56, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 56, 56, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 56, 56, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 56, 56, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 56, 56, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 28, 28, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 28, 28, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#  conv3_block2_0_bn (BatchNormal  (None, 28, 28, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 28, 28, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 28, 28, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 28, 28, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 28, 28, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 28, 28, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 28, 28, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 28, 28, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 28, 28, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 28, 28, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 28, 28, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 28, 28, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 28, 28, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 28, 28, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 28, 28, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 28, 28, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 28, 28, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 28, 28, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 28, 28, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 28, 28, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 28, 28, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 28, 28, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 28, 28, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 28, 28, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 28, 28, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 28, 28, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 28, 28, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 28, 28, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#  conv3_block10_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 28, 28, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 28, 28, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 28, 28, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 28, 28, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 28, 28, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 28, 28, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 28, 28, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 28, 28, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 28, 28, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 28, 28, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 28, 28, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 28, 28, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 14, 14, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 14, 14, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 14, 14, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 14, 14, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 14, 14, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 14, 14, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 14, 14, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 14, 14, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 14, 14, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 14, 14, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 14, 14, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 14, 14, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 14, 14, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 14, 14, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 14, 14, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 14, 14, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block6_1_conv[0][0]']
#  ization)
# ...
#  conv5_block24_concat (Concaten  (None, 7, 7, 1664)  0           ['conv5_block23_concat[0][0]',
#  ate)                                                             'conv5_block24_2_conv[0][0]']
#
#  conv5_block25_0_bn (BatchNorma  (None, 7, 7, 1664)  6656        ['conv5_block24_concat[0][0]']
#  lization)
#
#  conv5_block25_0_relu (Activati  (None, 7, 7, 1664)  0           ['conv5_block25_0_bn[0][0]']
#  on)
#
#  conv5_block25_1_conv (Conv2D)  (None, 7, 7, 128)    212992      ['conv5_block25_0_relu[0][0]']
#
#  conv5_block25_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 7, 7, 1696)  0           ['conv5_block24_concat[0][0]',
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 7, 7, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 7, 7, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 7, 7, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 7, 7, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 7, 7, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 7, 7, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 7, 7, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 7, 7, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 7, 7, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 7, 7, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 7, 7, 128)    225280      ['conv5_block28_0_relu[0][0]']
#  conv5_block28_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 7, 7, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 7, 7, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 7, 7, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 7, 7, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 7, 7, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 7, 7, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 7, 7, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 7, 7, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 7, 7, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 7, 7, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 7, 7, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 7, 7, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 7, 7, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 7, 7, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 7, 7, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 7, 7, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 7, 7, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 7, 7, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 7, 7, 1920)   0           ['bn[0][0]']
#
# ==================================================================================================
# Total params: 18,321,984
# Trainable params: 18,092,928
# Non-trainable params: 229,056
# __________________________________________________________________________________________________
